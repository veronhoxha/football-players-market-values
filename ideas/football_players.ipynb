# %%
import datadotworld as dw
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataset = dw.load_dataset('dcereijo/player-scores', force_update=True)

# %%
print(dataset.dataframes)
# Out:
# {'appearances': LazyLoadedValue(<pandas.DataFrame>), 'club_games': LazyLoadedValue(<pandas.DataFrame>), 'clubs': LazyLoadedValue(<pandas.DataFrame>), 'competitions': LazyLoadedValue(<pandas.DataFrame>)}

# %%
df = dataset.dataframes["appearances"]

# %%
print(df.columns)
# Out:
# Index(['appearance_id', 'game_id', 'player_id', 'player_club_id',
#        'player_current_club_id', 'date', 'player_name', 'competition_id',
#        'yellow_cards', 'red_cards', 'goals', 'assists', 'minutes_played'],
#       dtype='object')

# %%
3df[df.player_name == "Cristiano Ronaldo"]
# Out:
#         appearance_id  game_id  player_id  player_club_id  \
# 16458    2483945_8198  2483945       8198             418
# 19154    2481145_8198  2481145       8198             418
# 19852    2481146_8198  2481146       8198             418
# 22533    2475189_8198  2475189       8198             418
# 27236    2475204_8198  2475204       8198             418
# ...               ...      ...        ...             ...
# 1033384  3592218_8198  3592218       8198             985
# 1036696  3592170_8198  3592170       8198             985
# 1038856  3592202_8198  3592202       8198             985
# 1041374  3592219_8198  3592219       8198             985
# 1042271  3592187_8198  3592187       8198             985
#
#          player_current_club_id       date        player_name competition_id  \
# 16458                       985 2014-08-12  Cristiano Ronaldo            USC
# 19154                       985 2014-08-19  Cristiano Ronaldo            SUC
# ...

# %%
valuations = pd.read_csv('https://query.data.world/s/y4qg2twfvou4w2ghz6o3evju32g7yn?dws=00000') 
players = pd.read_csv('https://query.data.world/s/gksm6hx4xzgjaed7tia2uzpafwvyjo?dws=00000')
players_stats = pd.read_csv('https://query.data.world/s/bl3zxtm4dujmo3yfctx6ec5t7digv6?dws=00000') ### THIS ONE IS OLD (2018)

# %%
players[players.name.str.contains("Messi")]
# Out:
#        player_id first_name last_name              name  last_season  \
# 6381      401539        NaN   Messias           Messias         2019
# 16811     449151     Junior   Messias    Junior Messias         2022
# 24386      28003     Lionel     Messi      Lionel Messi         2022
# 24849     168199   Giuseppe   Messina  Giuseppe Messina         2012
#
#        current_club_id       player_code country_of_birth   city_of_birth  \
# 6381              2425           messias           Brazil     São Matheus
# 16811                5    junior-messias           Brazil  Belo Horizonte
# 24386              583      lionel-messi        Argentina         Rosario
# 24849             1627  giuseppe-messina            Italy            Enna
#
#       country_of_citizenship  ...   foot height_in_cm market_value_in_eur  \
# 6381                  Brazil  ...  right        192.0            800000.0
# 16811                 Brazil  ...   left        174.0           6000000.0
# ...

# %%
players_stats.columns
# Out:
# Index(['id', 'name', 'full_name', 'birth_date', 'age', 'height_cm',
#        'weight_kgs', 'positions', 'nationality', 'overall_rating', 'potential',
#        'value_euro', 'wage_euro', 'preferred_foot',
#        'international_reputation(1-5)', 'weak_foot(1-5)', 'skill_moves(1-5)',
#        'work_rate', 'body_type', 'release_clause_euro', 'club_team',
#        'club_rating', 'club_position', 'club_jersey_number', 'club_join_date',
#        'contract_end_year', 'national_team', 'national_rating',
#        'national_team_position', 'national_jersey_number', 'crossing',
#        'finishing', 'heading_accuracy', 'short_passing', 'volleys',
#        'dribbling', 'curve', 'freekick_accuracy', 'long_passing',
#        'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions',
#        'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
#        'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
# ...

# %%
players[(players.current_club_name.isna()) & (players.country_of_birth == "Argentina")]
# Out:
#        player_id first_name       last_name                 name  last_season  \
# 28          5890     Sergio         Almirón       Sergio Almirón         2013
# 291        58383    Gonzalo     Castillejos  Gonzalo Castillejos         2017
# 327        66587        NaN  Pato Rodríguez       Pato Rodríguez         2019
# 489       125735       Luis          Fariña          Luis Fariña         2018
# 532       148231      Lucas           Mugni          Lucas Mugni         2020
# ...          ...        ...             ...                  ...          ...
# 27532      40822      Mauro         Boselli        Mauro Boselli         2012
# 27899      27448     Marcos        Angeleri      Marcos Angeleri         2015
# 27995     324946    Emanuel        Cecchini     Emanuel Cecchini         2017
# 28255     153022    Nicolás          Blandi       Nicolás Blandi         2014
# 28277      55884      Pablo           Pérez          Pablo Pérez         2013
#
# ...

# %%
players.current_club_name.unique()
# Out:
# array(['Krylya Sovetov Samara', 'SC Freiburg', 'SC Heerenveen', nan,
#        'Ajax Amsterdam', 'Leicester City', 'St. Johnstone FC',
#        'Heart of Midlothian FC', 'Rangers FC', 'Aston Villa',
#        'Chelsea FC', 'Eintracht Frankfurt', 'RKC Waalwijk', 'RFC Seraing',
#        'Galatasaray', 'Paris Saint-Germain', 'FC Nantes',
#        'ACF Fiorentina', 'Getafe CF', 'Juventus FC', 'Elche CF',
#        'APO Levadiakos', 'Atlético de Madrid', 'KVC Westerlo',
#        'OFI Crete FC', 'Cercle Brugge', 'Fenerbahce', 'Sivasspor',
#        'Hibernian FC', 'Crystal Palace', 'Aberdeen FC', 'Panetolikos GFS',
#        'KV Oostende', 'Royal Antwerp FC', 'Brighton & Hove Albion',
#        'AFC Bournemouth', 'Gil Vicente FC', 'FC Augsburg', 'LOSC Lille',
#        'Bayer 04 Leverkusen', 'Aarhus GF', 'Aris Thessaloniki',
#        'KAA Gent', 'Olympique Marseille', 'Olympique Lyon',
#        'Olympiacos Piraeus', 'FC Paços de Ferreira', 'AC Horsens',
# ...

# %% [markdown]
# The FIFA 2022 Dataset can be found here: https://www.kaggle.com/datasets/stefanoleone992/fifa-22-complete-player-dataset/?select=players_22.csv
