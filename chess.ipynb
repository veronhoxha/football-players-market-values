# %%
import pandas as pd
import numpy as np
import random

# %%
chess = pd.read_csv('games.csv')
chess.head(3)
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
#
#   increment_code  white_id  white_rating   black_id  black_rating  \
# 0           15+2  bourgris          1500       a-00          1191
# 1           5+10      a-00          1322  skinnerua          1261
# 2           5+10    ischia          1496       a-00          1500
#
#                                                moves opening_eco  \
# 0  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# 1  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
# 2  e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...         C20
#
#                              opening_name  opening_ply
# 0        Slav Defense: Exchange Variation            5
# ...

# %%
'''Bayesian analysis allows you to make probabilistic inferences about the data, such as estimating the strength of a player, evaluating the likelihood of a specific move, or understanding the distribution of game outcomes.

    #   Here are the general steps to perform Bayesian statistical analysis on a chess dataset:

            1. Define Your Research Question: Start by specifying the research question or hypothesis you want to investigate with your chess dataset.
                     For example, you might want to estimate the Elo rating of a player, determine the probability of a player winning a game given certain conditions, or assess the impact of a specific opening move on the game's outcome.

            2. Choose the Appropriate Bayesian Model: Select a Bayesian model that suits your research question. 
                    Common models for analyzing chess data may include Bayesian Elo rating models, Bayesian networks for move analysis, or Bayesian logistic regression models for outcome prediction.

            3. Collect and Prepare Data: Ensure that your chess dataset is clean, complete, and in a format suitable for analysis. 
                    You might need data on player ratings, game outcomes, move sequences, and other relevant information.

            4. Prior Specification: Specify prior distributions for the parameters in your model. 
                    Priors represent your initial beliefs about the parameters before observing the data. In the context of chess, you may choose informative priors based on historical player ratings or non-informative priors when little prior knowledge is available.

            5. Likelihood Model: Define the likelihood function that describes the probability of observing the data given the model parameters.
                     For chess analysis, this could be the likelihood of a player's moves given their skill level, the likelihood of a specific outcome, or other relevant likelihood functions.

            6. Perform Bayesian Inference: Use a Bayesian inference framework, such as Markov Chain Monte Carlo (MCMC) methods (e.g., Stan, JAGS) or probabilistic programming languages (e.g., PyMC3, Edward), to estimate the posterior distributions of model parameters.
                     This involves sampling from the posterior using Bayesian methods.

            7. Interpret Results: Analyze the posterior distributions to draw conclusions and make inferences about your research question. 
                    You can estimate parameters, generate posterior predictive distributions, and calculate credible intervals.

            8. Validate and Test: Evaluate the performance of your Bayesian model by using techniques like cross-validation to assess predictive accuracy. 
                    Ensure that your model aligns with the underlying chess dynamics and produces reliable results.

            9. Visualize and Communicate Findings: Create visualizations and summary statistics to effectively communicate your findings.
                     Visual representations, such as posterior density plots or predictive distributions, can help convey the results.

            10.Iterate and Refine: Depending on your results, you may need to refine your model, modify your priors, or adjust your data preprocessing to improve the accuracy of your Bayesian analysis.
            '''
