# %%
import pandas as pd
from fuzzywuzzy import fuzz

# %%
valuations = pd.read_csv('https://query.data.world/s/y4qg2twfvou4w2ghz6o3evju32g7yn?dws=00000') 
players = pd.read_csv('https://query.data.world/s/gksm6hx4xzgjaed7tia2uzpafwvyjo?dws=00000')

# %%
players
# Out:
#        player_id first_name last_name              name  last_season  \
# 6381      401539        NaN   Messias           Messias         2019
# 16811     449151     Junior   Messias    Junior Messias         2022
# 24386      28003     Lionel     Messi      Lionel Messi         2022
# 24849     168199   Giuseppe   Messina  Giuseppe Messina         2012
#
#        current_club_id       player_code country_of_birth   city_of_birth  \
# 6381              2425           messias           Brazil     São Matheus
# 16811                5    junior-messias           Brazil  Belo Horizonte
# 24386              583      lionel-messi        Argentina         Rosario
# 24849             1627  giuseppe-messina            Italy            Enna
#
#       country_of_citizenship  ...   foot height_in_cm market_value_in_eur  \
# 6381                  Brazil  ...  right        192.0            800000.0
# 16811                 Brazil  ...   left        174.0           6000000.0
# ...

# %%
players[players.name.str.contains('Messi')]
# Out:
#        player_id first_name last_name              name  last_season  \
# 6381      401539        NaN   Messias           Messias         2019
# 16811     449151     Junior   Messias    Junior Messias         2022
# 24386      28003     Lionel     Messi      Lionel Messi         2022
# 24849     168199   Giuseppe   Messina  Giuseppe Messina         2012
#
#        current_club_id       player_code country_of_birth   city_of_birth  \
# 6381              2425           messias           Brazil     São Matheus
# 16811                5    junior-messias           Brazil  Belo Horizonte
# 24386              583      lionel-messi        Argentina         Rosario
# 24849             1627  giuseppe-messina            Italy            Enna
#
#       country_of_citizenship  ...   foot height_in_cm market_value_in_eur  \
# 6381                  Brazil  ...  right        192.0            800000.0
# 16811                 Brazil  ...   left        174.0           6000000.0
# ...

# %%
players[players.name.str.contains('Ronaldo')]
# Out:
#        player_id first_name          last_name               name  \
# 6705      742506      Fábio            Ronaldo      Fábio Ronaldo
# 7538      236952    Ronaldo             Mendes     Ronaldo Mendes
# 7705      309487    Ronaldo               Peña       Ronaldo Peña
# 9734      434676    Ronaldo             Vieira     Ronaldo Vieira
# 11646     565836    Ronaldo              Shani      Ronaldo Shani
# 21985     340531    Ronaldo            Tavares    Ronaldo Tavares
# 24801     146660        NaN            Ronaldo            Ronaldo
# 26079       8198        NaN  Cristiano Ronaldo  Cristiano Ronaldo
#
#        last_season  current_club_id        player_code country_of_birth  \
# 6705          2022             2425      fabio-ronaldo         Portugal
# 7538          2021              126     ronaldo-mendes           Brazil
# 7705          2017              979       ronaldo-pena        Venezuela
# 9734          2022              416     ronaldo-vieira    Guinea-Bissau
# ...

# %%
valuations
# Out:
#         player_id  last_season             datetime        date    dateweek  \
# 0            3132         2013  2003-12-09 00:00:00  2003-12-09  2003-12-08
# 1            6893         2012  2003-12-15 00:00:00  2003-12-15  2003-12-15
# 2              10         2015  2004-10-04 00:00:00  2004-10-04  2004-10-04
# 3              26         2017  2004-10-04 00:00:00  2004-10-04  2004-10-04
# 4              65         2015  2004-10-04 00:00:00  2004-10-04  2004-10-04
# ...           ...          ...                  ...         ...         ...
# 424318     158071         2015  2023-05-17 00:00:00  2023-05-17  2023-05-15
# 424319     187191         2016  2023-05-17 00:00:00  2023-05-17  2023-05-15
# 424320     279110         2015  2023-05-17 00:00:00  2023-05-17  2023-05-15
# 424321     863829         2022  2023-05-17 00:00:00  2023-05-17  2023-05-15
# 424322     405676         2018  2023-12-19 00:00:00  2023-12-19  2023-12-18
#
#         market_value_in_eur  n  current_club_id  \
# ...

# %%
merge_df = pd.merge(players, valuations, on='player_id')
merge_df[merge_df.name.str.contains('Lionel Messi')]
# Out:
#         player_id first_name last_name          name  last_season_x  \
# 364881      28003     Lionel     Messi  Lionel Messi           2022
# 364882      28003     Lionel     Messi  Lionel Messi           2022
# 364883      28003     Lionel     Messi  Lionel Messi           2022
# 364884      28003     Lionel     Messi  Lionel Messi           2022
# 364885      28003     Lionel     Messi  Lionel Messi           2022
# 364886      28003     Lionel     Messi  Lionel Messi           2022
# 364887      28003     Lionel     Messi  Lionel Messi           2022
# 364888      28003     Lionel     Messi  Lionel Messi           2022
# 364889      28003     Lionel     Messi  Lionel Messi           2022
# 364890      28003     Lionel     Messi  Lionel Messi           2022
# 364891      28003     Lionel     Messi  Lionel Messi           2022
# 364892      28003     Lionel     Messi  Lionel Messi           2022
# 364893      28003     Lionel     Messi  Lionel Messi           2022
# ...

# %%
fifa22 = pd.read_csv('../players_22.csv')
fifa22
# Out:
# C:\Users\Veronii\AppData\Local\Temp\ipykernel_72624\3833316026.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   fifa22 = pd.read_csv('../players_22.csv')
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# ...

# %%
def get_closest_match(x, other_names, scorer=fuzz.partial_ratio, cutoff=90):
    best_match = process.extractOne(x, other_names, scorer=scorer)
    return best_match[0] if best_match[1] >= cutoff else None

# %%
df1['matched_name'] = players['name'].apply(lambda x: get_closest_match(x, fifa22['short_name'].tolist()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Veronii\AppData\Local\Programs\Python\Python310\lib\site-packages\fuzzywuzzy\process.py:108, in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     106 try:
#     107     # See if choices is a dictionary-like object.
# --> 108     for key, choice in choices.items():
#     109         processed = pre_processor(processor(choice))
#
# AttributeError: 'list' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Veronii\Desktop\advanced_stats\ideas\combine.ipynb Cell 9 line 1
# ...
